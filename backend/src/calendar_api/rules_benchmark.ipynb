# %%
import os
import json
import openai
from dotenv import load_dotenv
from sentence_transformers import SentenceTransformer
import time
import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity
# from ..rules import rules_agent

load_dotenv()

client = openai.OpenAI(
    api_key = "fu.so@northeastern.edu:03712",
    base_url = "https://nerc.guha-anderson.com/v1")

# %%
with open('../../bench_data/rules_benchmark.json', 'r') as file:
  benchmark = json.load(file)

# %%
model = SentenceTransformer('all-MiniLM-L6-v2')

# %%
SYSTEM_PROMPT = """
I want you to become my Expert Prompt Creator. Only answer with a list of rules and preferences about 
a calendar schedule from the Google Calendar API.

These responses will be used to have a better understanding of patterns within a users schedule.
The purpose is to prompt make suggestions for when new event requests are made
Longer calendar schedules should have more rules and suggests.

Your response will be in the following format:

"
Rules:
1. Meetings should not overlap.
2. Breaks of at least 15 minutes should be scheduled between meetings longer than 1 hour.
3. Work hours are from 9:00 AM to 6:00 PM.
4. No meetings should be scheduled before 10:00 AM on Mondays.
5. Lunch breaks should be scheduled between 12:00 PM and 1:30 PM.
6. Recurring meetings should follow a consistent pattern (e.g., every Monday at 3:00 PM).
7. Personal time should be blocked out to avoid conflicts with work.

Suggestions:
1. Fridays are remote. More flexibility for events.
2. Morning meetings are prefered on Fridays.
3. Exceptions are okay for important events, personal or professional.
"

"""

with open('./events/events_1.json', 'r') as file:
    EVENTS_1 = json.load(file)

with open('./events/events_2.json', 'r') as file:
    EVENTS_2 = json.load(file)

with open('./events/events_3.json', 'r') as file:
    EVENTS_3 = json.load(file)

with open('./events/events_4.json', 'r') as file:
    EVENTS_4 = json.load(file)

EVENTS_1_RULES = """
Rules:
1. Classes should be back to back and in the mornings.
2. Lunch time should be set aside for breaks and socialization.
3. Meetings should be in the evenings.
4. Social events and hangouts are usually reserved for the weekends.

Suggestions:
1. Gym workouts can be skipped if there is an important meeting or deadline.
"""

EVENTS_2_RULES = """
Rules:
1. Classes should have gaps for break.
2. Fridays should be class-free for socializing.

Suggestions:
"""

EVENTS_3_RULES = """
Rules:
1. Mornings are never free because of stand ups.
2. Typical 9-5 schedule so the day is mainly reserved for work.
3. Schedule accomodates time for hobbies like sewing and thrifting.

Suggestions:
1. Consider having more social events and hangouts since
employees do not have homework.
"""

USER_PREFIX = "Parse this calendar: "

PROMPT_PREFIX = [
    { "role": "system", "content": SYSTEM_PROMPT },
    # Example 1
    { "role": "user", "content": USER_PREFIX + json.dumps(EVENTS_1)},
    { "role": "assistant", "content": EVENTS_1_RULES },

    # Example 2
    { "role": "user", "content": USER_PREFIX + json.dumps(EVENTS_2)},
    { "role": "assistant", "content": EVENTS_2_RULES },

    # Examples 3
    { "role": "user", "content": USER_PREFIX + json.dumps(EVENTS_3)},
    { "role": "assistant", "content": EVENTS_3_RULES }
]

# %%
def rules_agent(user_query, MODEL):
    messages = PROMPT_PREFIX + [{"role": "user", "content": user_query}]
    resp = client.chat.completions.create(
        model = MODEL,
        messages=messages,
        temperature=0.2
    ).choices[0].message.content
    messages.append({"role": "assistant", "content": resp})
    # print(resp)
    return resp

# %%
def eval_rules_benchmark(model_name):
  MODEL = model_name
  # output = pd.DataFrame(columns=['username', 'generated_rules', 'generation_time_elapsed', "num_events", 'expected_rules', 'similarity'])
  output = []
  for item in benchmark['calendars']:
    row = {}
    row['username'] = item['username']
    rule = f"Rules:\n"
    count = 1
    for r in item['output']['rules']:
      new_rule= f"{count}. {r}\n"
      rule += new_rule
      count+= 1

    count = 1
    suggestion = f"Suggestions: \n"

    for sugg in item['output']['suggestions']:
      new_sugg = f"{count}. {sugg}\n"
      suggestion += new_sugg
      count +=1
    
    expected_rule = rule + suggestion
    row['expected_rules'] = expected_rule

    start_time = time.perf_counter()
    gen_rules = rules_agent(json.dumps(item['input']['events']), MODEL)
    end_time = time.perf_counter()
    execution_time = end_time - start_time

    row['generated_rules'] = gen_rules
    row['generation_time_elapsed'] = execution_time
    
    num_events = len(item['input']['events'])
    row['num_events'] = num_events

    
    exp_embedding = model.encode(expected_rule)
    act_embedding = model.encode(gen_rules)
    similarity = cosine_similarity([exp_embedding], [act_embedding])[0][0]

    row['similarity'] = similarity
    output.append(row)
  output_df = pd.DataFrame(output)
  return output_df

# %%
MODEL = "llama3p3-70b-instruct"
# MODEL = "llama3p1-8b-instruct"
# MODEL = "gpt-4o-mini"

# %%
bench_8b = eval_rules_benchmark("llama3p1-8b-instruct")
bench_8b
# Out:
#                 username                                     expected_rules  \
# 0               student1  Rules:\n1. Morning classes should be scheduled...
# 1            researcher1  Rules:\n1. Lab work should be scheduled in the...
# 2         remote_worker1  Rules:\n1. Days start with physical exercise b...
# 3          grad_student1  Rules:\n1. Mornings are dedicated to thesis wr...
# 4                parent1  Rules:\n1. School transportation times are non...
# 5          entrepreneur1  Rules:\n1. Every day begins with planning and ...
# 6     healthcare_worker1  Rules:\n1. Shift times are fixed and non-negot...
# 7               teacher1  Rules:\n1. Class schedules are fixed and non-n...
# 8     business_traveler1  Rules:\n1. Allow at least 90 minutes buffer be...
# 9            freelancer1  Rules:\n1. Mornings are dedicated to the most ...
# 10      startup_founder1  Rules:\n1. Personal development must happen fi...
# 11  high_school_student1  Rules:\n1. School classes follow a fixed sched...
# 12              retiree1  Rules:\n1. Physical activities are scheduled i...
# 13      weekend_planner1  Rules:\n1. Weekend mornings start with outdoor...
# 14          gradstudent1  Rules:\n1. Research lab work is consistently s...
# 15             designer1  Rules:\n1. Morning meditation is a daily routi...
# 16             salesrep3  Rules:\n1. Weekday mornings begin with an 8:30...
# 17                test10  Rules:\n1. Early mornings are reserved for wel...
# 18                test11  Rules:\n1. Teaching responsibilities are conce...
# 19                test12  Rules:\n1. Hospital rounds are always early in...
# 20                test13  Rules:\n1. Every day begins with meditation to...
# 21                test14  Rules:\n1. Mornings are dedicated to uninterru...
# 22                test15  Rules:\n1. Every day begins with morning pages...
# 23                test16  Rules:\n1. Classes are scheduled in the mornin...
# 24                test17  Rules:\n1. Team meetings happen first thing in...
# 25                test18  Rules:\n1. Mornings begin with a quick breakfa...
# 26                test19  Rules:\n1. Classes are scheduled back-to-back ...
# 27                test20  Rules:\n1. Day begins with mindfulness practic...
#
#                                       generated_rules  \
# 0   Rules:\n1. Classes should be back to back with...
# 1   Rules:\n1. Research meetings are scheduled in ...
# 2   Rules:\n1. Mornings are reserved for exercise ...
# 3   Rules:\n1. Thesis writing is a priority and sh...
# 4   Rules:\n1. School drop-off and pick-up are sch...
# 5   Rules:\n1. Mornings are reserved for personal ...
# 6   Rules:\n1. Hospital shifts are long and take u...
# 7   Rules:\n1. School days start early with prep t...
# 8   Rules:\n1. Travel days are reserved for flight...
# 9   Rules:\n1. Daily routine includes morning rout...
# 10  Rules:\n1. Daily stand-up meetings are schedul...
# 11  Rules:\n1. Classes should be back to back with...
# 12  Rules:\n1. Mornings are reserved for exercise ...
# 13  Rules:\n1. Weekends are reserved for relaxatio...
# 14  Rules:\n1. Meetings and events should be sched...
# 15  Rules:\n1. Daily meditation is a priority and ...
# 16  Rules:\n1. Daily team stand-up meetings are sc...
# 17  Rules:\n1. Recurring events should follow a co...
# 18  Rules:\n1. Monday, Wednesday, and Friday are r...
# 19  Rules:\n1. Monday, Wednesday, and Friday are r...
# 20  Rules:\n1. Daily meditation is a must.\n2. Con...
# 21  Rules:\n1. Work hours are from 9:00 AM to 6:00...
# 22  Rules:\n1. Daily morning writing practice is a...
# 23  Rules:\n1. Classes should be scheduled in the ...
# 24  Rules:\n1. Meetings should not overlap.\n2. Wo...
# 25  Rules:\n1. Mornings are reserved for breakfast...
# 26  Rules:\n1. Classes should be back to back with...
# 27  Rules:\n1. Mornings are reserved for meditatio...
#
#     generation_time_elapsed  num_events  similarity
# 0                  0.949387           3    0.796914
# 1                  0.699937           4    0.840207
# 2                  1.021070           6    0.761893
# 3                  1.072154           5    0.841180
# 4                  0.749867           9    0.777388
# 5                  1.300616           7    0.662427
# 6                  1.109100           6    0.690058
# 7                  1.042858          10    0.778981
# 8                  1.209844           8    0.701338
# 9                  1.226023           9    0.662304
# 10                 1.248969          10    0.803720
# 11                 9.810714           4    0.798319
# 12                 0.943367           3    0.704633
# 13                 1.027902           4    0.863444
# 14                 1.432095          25    0.737091
# 15                 1.291228          30    0.835999
# 16                 4.828851          32    0.820072
# 17                 1.333487           7    0.617261
# 18                 0.790598           8    0.587097
# 19                 1.169680           9    0.727980
# 20                 1.225404          10    0.731623
# 21                 1.611783          11    0.700480
# 22                 4.187787          12    0.792582
# 23                 5.395850           3    0.794937
# 24                 0.754498           4    0.719899
# 25                 1.010357           4    0.628514
# 26                 0.906299           4    0.820200
# 27                 0.930122           5    0.745663

# %%
bench_70b = eval_rules_benchmark("llama3p3-70b-instruct")
bench_70b
# Out:
#                 username                                     expected_rules  \
# 0               student1  Rules:\n1. Morning classes should be scheduled...
# 1            researcher1  Rules:\n1. Lab work should be scheduled in the...
# 2         remote_worker1  Rules:\n1. Days start with physical exercise b...
# 3          grad_student1  Rules:\n1. Mornings are dedicated to thesis wr...
# 4                parent1  Rules:\n1. School transportation times are non...
# 5          entrepreneur1  Rules:\n1. Every day begins with planning and ...
# 6     healthcare_worker1  Rules:\n1. Shift times are fixed and non-negot...
# 7               teacher1  Rules:\n1. Class schedules are fixed and non-n...
# 8     business_traveler1  Rules:\n1. Allow at least 90 minutes buffer be...
# 9            freelancer1  Rules:\n1. Mornings are dedicated to the most ...
# 10      startup_founder1  Rules:\n1. Personal development must happen fi...
# 11  high_school_student1  Rules:\n1. School classes follow a fixed sched...
# 12              retiree1  Rules:\n1. Physical activities are scheduled i...
# 13      weekend_planner1  Rules:\n1. Weekend mornings start with outdoor...
# 14          gradstudent1  Rules:\n1. Research lab work is consistently s...
# 15             designer1  Rules:\n1. Morning meditation is a daily routi...
# 16             salesrep3  Rules:\n1. Weekday mornings begin with an 8:30...
# 17                test10  Rules:\n1. Early mornings are reserved for wel...
# 18                test11  Rules:\n1. Teaching responsibilities are conce...
# 19                test12  Rules:\n1. Hospital rounds are always early in...
# 20                test13  Rules:\n1. Every day begins with meditation to...
# 21                test14  Rules:\n1. Mornings are dedicated to uninterru...
# 22                test15  Rules:\n1. Every day begins with morning pages...
# 23                test16  Rules:\n1. Classes are scheduled in the mornin...
# 24                test17  Rules:\n1. Team meetings happen first thing in...
# 25                test18  Rules:\n1. Mornings begin with a quick breakfa...
# 26                test19  Rules:\n1. Classes are scheduled back-to-back ...
# 27                test20  Rules:\n1. Day begins with mindfulness practic...
#
#                                       generated_rules  \
# 0   Rules:\n1. Classes are scheduled back-to-back ...
# 1   Rules:\n1. Work hours are typically from 9:00 ...
# 2   Rules:\n1. Mornings are reserved for personal ...
# 3   Rules:\n1. Mornings are reserved for focused w...
# 4   Rules:\n1. Work sessions are split into mornin...
# 5   Rules:\n1. Mornings are reserved for personal ...
# 6   Rules:\n1. Work shifts are long and tiring, re...
# 7   Rules:\n1. The schedule is highly structured a...
# 8   Rules:\n1. Travel days should be kept free of ...
# 9   Rules:\n1. Morning routines are consistent and...
# 10  Rules:\n1. Mornings are reserved for personal ...
# 11  Rules:\n1. Classes are typically scheduled in ...
# 12  Rules:\n1. Mornings are reserved for personal ...
# 13  Rules:\n1. Saturdays are reserved for relaxati...
# 14  Rules:\n1. Mondays and Wednesdays are reserved...
# 15  Rules:\n1. Daily meditation is a priority, sch...
# 16  Rules:\n1. Daily stand-up meetings are a prior...
# 17  Rules:\n1. Mondays, Wednesdays, and Fridays st...
# 18  Rules:\n1. Mondays, Wednesdays, and Fridays ar...
# 19  Rules:\n1. Mondays, Wednesdays, and Fridays ar...
# 20  Rules:\n1. Mornings are reserved for meditatio...
# 21  Rules:\n1. Mondays are for sprint planning and...
# 22  Rules:\n1. Mornings are dedicated to creative ...
# 23  Rules:\n1. Classes are typically held in the m...
# 24  Rules:\n1. Mornings are reserved for team stan...
# 25  Rules:\n1. Mornings are reserved for creative ...
# 26  Rules:\n1. Classes are typically scheduled in ...
# 27  Rules:\n1. Mornings are reserved for personal ...
#
#     generation_time_elapsed  num_events  similarity
# 0                  1.762825           3    0.784107
# 1                  1.565339           4    0.826093
# 2                  1.496518           6    0.723709
# 3                  1.098560           5    0.888138
# 4                  1.658766           9    0.801791
# 5                  1.334277           7    0.767478
# 6                  2.195830           6    0.822336
# 7                  2.783073          10    0.781199
# 8                 12.916939           8    0.824497
# 9                  1.901354           9    0.710601
# 10                 1.690318          10    0.763377
# 11                 1.786374           4    0.760591
# 12                 1.381644           3    0.687475
# 13                 1.393322           4    0.805392
# 14                 1.848898          25    0.823342
# 15                 2.268689          30    0.864809
# 16                 3.175759          32    0.807682
# 17                 2.451135           7    0.646159
# 18                 2.178813           8    0.661025
# 19                 2.008004           9    0.815639
# 20                 1.777121          10    0.847492
# 21                 1.953133          11    0.819651
# 22                 3.075808          12    0.831488
# 23                 1.490120           3    0.780472
# 24                 4.593806           4    0.797247
# 25                 2.576885           4    0.684577
# 26                 2.184575           4    0.809198
# 27                 5.070071           5    0.760055

# %%
bench_4o = eval_rules_benchmark("gpt-4o-mini")
bench_4o
# Out:
#                 username                                     expected_rules  \
# 0               student1  Rules:\n1. Morning classes should be scheduled...
# 1            researcher1  Rules:\n1. Lab work should be scheduled in the...
# 2         remote_worker1  Rules:\n1. Days start with physical exercise b...
# 3          grad_student1  Rules:\n1. Mornings are dedicated to thesis wr...
# 4                parent1  Rules:\n1. School transportation times are non...
# 5          entrepreneur1  Rules:\n1. Every day begins with planning and ...
# 6     healthcare_worker1  Rules:\n1. Shift times are fixed and non-negot...
# 7               teacher1  Rules:\n1. Class schedules are fixed and non-n...
# 8     business_traveler1  Rules:\n1. Allow at least 90 minutes buffer be...
# 9            freelancer1  Rules:\n1. Mornings are dedicated to the most ...
# 10      startup_founder1  Rules:\n1. Personal development must happen fi...
# 11  high_school_student1  Rules:\n1. School classes follow a fixed sched...
# 12              retiree1  Rules:\n1. Physical activities are scheduled i...
# 13      weekend_planner1  Rules:\n1. Weekend mornings start with outdoor...
# 14          gradstudent1  Rules:\n1. Research lab work is consistently s...
# 15             designer1  Rules:\n1. Morning meditation is a daily routi...
# 16             salesrep3  Rules:\n1. Weekday mornings begin with an 8:30...
# 17                test10  Rules:\n1. Early mornings are reserved for wel...
# 18                test11  Rules:\n1. Teaching responsibilities are conce...
# 19                test12  Rules:\n1. Hospital rounds are always early in...
# 20                test13  Rules:\n1. Every day begins with meditation to...
# 21                test14  Rules:\n1. Mornings are dedicated to uninterru...
# 22                test15  Rules:\n1. Every day begins with morning pages...
# 23                test16  Rules:\n1. Classes are scheduled in the mornin...
# 24                test17  Rules:\n1. Team meetings happen first thing in...
# 25                test18  Rules:\n1. Mornings begin with a quick breakfa...
# 26                test19  Rules:\n1. Classes are scheduled back-to-back ...
# 27                test20  Rules:\n1. Day begins with mindfulness practic...
#
#                                       generated_rules  \
# 0   \nRules:\n1. Classes should start no earlier t...
# 1   \nRules:\n1. Mornings are reserved for laborat...
# 2   \nRules:\n1. Mornings start with exercise to p...
# 3   \nRules:\n1. Mornings are dedicated to focused...
# 4   \nRules:\n1. Mornings are reserved for school ...
# 5   \nRules:\n1. Mornings are reserved for persona...
# 6   \nRules:\n1. Morning shifts start at 7:00 AM a...
# 7   \nRules:\n1. Classes should start promptly aft...
# 8   \nRules:\n1. Travel events should allow for su...
# 9   \nRules:\n1. Daily morning routines are essent...
# 10  \nRules:\n1. Daily morning routines are priori...
# 11  \nRules:\n1. Classes should start early in the...
# 12  \nRules:\n1. Mornings are reserved for exercis...
# 13  \nRules:\n1. Weekends are reserved for social ...
# 14  \nRules:\n1. Weekly commitments should be sche...
# 15  \nRules:\n1. Daily meditation is scheduled eve...
# 16  \nRules:\n1. Daily stand-up meetings are sched...
# 17  \nRules:\n1. Mornings are reserved for yoga an...
# 18  \nRules:\n1. Teaching hours are set in the mor...
# 19  \nRules:\n1. Morning rounds and clinic hours a...
# 20  \nRules:\n1. Daily meditation is prioritized f...
# 21  \nRules:\n1. Work hours are from 9:00 AM to 6:...
# 22  \nRules:\n1. Daily writing practice is priorit...
# 23  \nRules:\n1. Classes should be scheduled in th...
# 24  \nRules:\n1. Daily standup meetings are schedu...
# 25  \nRules:\n1. Mornings start with breakfast and...
# 26  \nRules:\n1. Classes should be scheduled with ...
# 27  \nRules:\n1. Mornings are reserved for meditat...
#
#     generation_time_elapsed  num_events  similarity
# 0                  2.505885           3    0.791710
# 1                  1.910121           4    0.823787
# 2                  2.143448           6    0.791416
# 3                  2.405523           5    0.797153
# 4                  2.284500           9    0.829432
# 5                  2.948586           7    0.757538
# 6                  2.578850           6    0.822937
# 7                  4.854128          10    0.828268
# 8                  2.642004           8    0.809789
# 9                  2.453260           9    0.712783
# 10                 2.361154          10    0.795178
# 11                 2.155985           4    0.869998
# 12                 1.978065           3    0.757620
# 13                 2.363480           4    0.846448
# 14                 1.966304          25    0.791010
# 15                 2.372419          30    0.847950
# 16                 2.702208          32    0.761428
# 17                 2.353328           7    0.782502
# 18                 2.311296           8    0.840027
# 19                 1.946255           9    0.834533
# 20                 5.277503          10    0.678675
# 21                 3.290511          11    0.789557
# 22                 5.405729          12    0.800642
# 23                 1.946496           3    0.815105
# 24                 1.651620           4    0.778856
# 25                 1.760308           4    0.901944
# 26                 1.521361           4    0.771742
# 27                 1.358613           5    0.741949

# %%
### accuracy  average_time_elapsed
# MODEL = "llama3p3-70b-instruct"
# # MODEL = "llama3p1-8b-instruct"
# # MODEL = "gpt-4o-mini"
threshholds = [.75, .78, .80]


dfs = []

for th in threshholds:
  metrics = []
  row_8b = {}
  row_8b['average_time_elapsed'] = bench_8b['generation_time_elapsed'].mean()
  bench_8b['is_correct'] = bench_8b['similarity'] >= th
  accuracy_8b = bench_8b['is_correct'].mean()
  row_8b['accuracy'] = accuracy_8b
  row_8b['model'] = "llama3p1-8b-instruct"
  row_8b['threshhold'] = th
  metrics.append(row_8b)

  row_70b = {}
  row_70b['average_time_elapsed'] = bench_70b['generation_time_elapsed'].mean()
  bench_70b['is_correct'] = bench_70b['similarity'] >= th
  accuracy_70b = bench_70b['is_correct'].mean()
  row_70b['accuracy'] = accuracy_70b
  row_70b['model'] = "llama3p3-70b-instruct"
  row_70b['threshhold'] = th
  metrics.append(row_70b)

  row_4o = {}
  row_4o['average_time_elapsed'] = bench_4o['generation_time_elapsed'].mean()
  bench_4o['is_correct'] = bench_4o['similarity'] >= th
  accuracy_4o = bench_4o['is_correct'].mean()
  row_4o['accuracy'] = accuracy_4o
  row_4o['model'] = "gpt-4o-mini"
  row_4o['threshhold'] = th
  metrics.append(row_4o)

  df = pd.DataFrame(metrics)
  dfs.append(df)

# %%
for df in dfs:
  display(df)
# Out:
#    average_time_elapsed  accuracy                  model  threshhold
# 0              1.795709  0.500000   llama3p1-8b-instruct        0.75
# 1              2.557784  0.785714  llama3p3-70b-instruct        0.75
# 2              2.551748  0.892857            gpt-4o-mini        0.75
#    average_time_elapsed  accuracy                  model  threshhold
# 0              1.795709  0.392857   llama3p1-8b-instruct        0.78
# 1              2.557784  0.642857  llama3p3-70b-instruct        0.78
# 2              2.551748  0.714286            gpt-4o-mini        0.78
#    average_time_elapsed  accuracy                  model  threshhold
# 0              1.795709  0.250000   llama3p1-8b-instruct         0.8
# 1              2.557784  0.500000  llama3p3-70b-instruct         0.8
# 2              2.551748  0.464286            gpt-4o-mini         0.8
